# %%
import pandas as pd

# %%
#pd.Series(col_name,index)
#Series
a=["Udaya","Harini","Ramya","Yashu","Sriya"]
r=pd.Series(a,index=[34,53,12,76,34])
print(r)
# Out:
# 34     Udaya
# 53    Harini
# 12     Ramya
# 76     Yashu
# 34     Sriya
# dtype: object

# %%
a=["Udaya","Harini","Ramya","Yashu","Sriya"]
index=[34,53,12,76,34]
r=pd.Series(a,index)
print(r)
# Out:
# 34     Udaya
# 53    Harini
# 12     Ramya
# 76     Yashu
# 34     Sriya
# dtype: object

# %%
#loading csv

dia=pd.read_csv("/content/diabetcsv (1).csv")
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
#loading csv

dia=pd.read_csv("/content/diabetcsv (1).csv",sep=",")
dia
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
grad=pd.read_csv("/content/grades_withnulls.txt",sep=",")
grad
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
demo=pd.read_csv("/content/demodt.txt",sep=",")
demo
# Out:
#    State  Literacy  Cleanliness  Crime_Rate  Good
# 0      A        92           90          54     0
# 1      B        56           67          50     1
# 2      C        78           85          62     0
# 3      D        63           72          48     1
# 4      E        85           79          55     0
# 5      F        71           68          58     0
# 6      G        80           83          51     0
# 7      H        67           74          47     1
# 8      I        89           88          53     0
# 9      J        58           65          49     1
# 10     K        82           81          60     0
# 11     L        75           78          57     0
# 12     M        69           70          46     1
# 13     N        87           86          52     0
# 14     O        61           63          45     1
# 15     P        93           91          56     0
# 16     Q        55           66          61     0
# 17     R        76           77          59     0
# ...

# %%
diaxl=pd.read_excel("/content/diabetes (1).xlsx")
diaxl
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
diaxl=pd.read_excel("/content/diabetes (1).xlsx",sheet_name="dora")
diaxl
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
diaxl.describe() #describing a dataframe
# Out:
#        Dead Alive
# count     5     5
# unique    1     1
# top     yes    no
# freq      5     5

# %%
diaxl.shape
# Out:
# (5, 2)

# %%
grad=pd.read_csv("/content/grades_withnulls.txt",sep=",")
print(grad.shape)
print(grad.shape[0])
print(grad.shape[1])
# Out:
# (17, 1)
# 17
# 1

# %%
#data cleaning - dealing with missing values
#know where there is NaN - not a value
grad=pd.read_csv("/content/grades_withnulls.txt")
print(grad.isnull())
# Out:
#     Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# 5                                        False
# 6                                        False
# 7                                        False
# 8                                        False
# 9                                        False
# 10                                       False
# 11                                       False
# 12                                       False
# 13                                       False
# 14                                       False
# 15                                       False
# 16                                       False

# %%
hi=pd.read_csv("/content/grades_withnulls.csv")
print(hi.isnull())
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
hi=pd.read_csv("/content/grades_withnulls.csv")
print(hi.isnull().sum())
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %%
print(hi.dropna())
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
hi
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
print(hi.dropna(inplace=True))
hi
# Out:
# None
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
hi
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
hi2=pd.read_csv("/content/grades_withnulls.csv")
hi2.fillna(555,inplace=True)
hi2
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
hi2=pd.read_csv("/content/grades_withnulls.csv")
mv = hi2['SEM1'].mean()
print(mv)
hi2.fillna(mv,inplace=True)
hi2
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
hi2=pd.read_csv("/content/grades_withnulls.csv")
mv = hi2['SEM1'].mean()
print(mv)
hi2.fillna(mv,inplace=True)
hi2
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#access the data
#loc = integers location,index
#loc = field names, index
#dfname.loc[index]--->rows
#dfname.loc[st:stop]---->arrange of rows
#dfname.loc[r_ind,col_col]--->rows&col
hi2.loc[0]#first record
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
hi2.loc[0:5] #first five records
# Out:
#     Names Initials  SEM1  SEM2       SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.900000    A+       1
# 1  Rajesh        M   8.9   9.1   9.300000     A       1
# 2  Kissan        V   9.9   9.8  10.000000     A       0
# 3    Mary        N   7.7   8.0   8.992857     B       0
# 4    Jeen        K   9.8   9.1   9.900000    A+       1
# 5     Raj        M   8.9   9.1   9.300000     A       1

# %%
hi2.loc[0:6,"SEM1"]
# Out:
# 0    9.8
# 1    8.9
# 2    9.9
# 3    7.7
# 4    9.8
# 5    8.9
# 6    9.9
# Name: SEM1, dtype: float64

# %%
hi2.loc[0:6,"SEM1"]#accepting integer as parameters i.e,col name should be mensions as per indexes(range of indexes)
# Out:
# 0    9.8
# 1    8.9
# 2    9.9
# 3    7.7
# 4    9.8
# 5    8.9
# 6    9.9
# Name: SEM1, dtype: float64

# %%
hi[hi.Grade=='A']
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0

# %%
hi[hi.SEM2==10] #show the people who got 10
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0   Joe        K   9.8  10.0   9.9    A+       1

# %%
#get the records who scored 9.3 in SEM3

hi[hi.SEM3 ==9.3]
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1

# %%
hi.loc[hi['SEM1']> 9.8,['Names']] # prints names of students who scored more than 9.8 in SEM1
# Out:
#      Names
# 2   Kissan
# 6   Hassan
# 15    Sana

# %%
#access the grades of students who score >9.8 in SEM1
hi.loc[hi['SEM1']>9.8,['Grade']]
# Out:
#    Grade
# 2      A
# 6      A
# 15     A

# %%
#access the grades of students who score >9.7 in SEM1
hi.loc[hi['SEM1']>9.7,['Grade']]
# Out:
#    Grade
# 0     A+
# 2      A
# 4     A+
# 6      A
# 12    A+
# 15     A

# %%
#to remove duplicate records

hi.drop_duplicates()
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#to remove duplicate records

hi.drop_duplicates()
hi
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#to remove duplicate records

hi.drop_duplicates(inplace=True)
hi
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#pints first n no of records
hi.head(7)
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 1  Rajesh        M   8.9   9.1   9.3     A       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1
# 5     Raj        M   8.9   9.1   9.3     A       1
# 6  Hassan        V   9.9   9.0   9.2     A       1
# 7    Mari        N   7.7   8.0   7.1     B       1

# %%
hi.tail(7)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
#Accessing specing row and column
print(hi2[hi2.index==3])
# Out:
#   Names Initials  SEM1  SEM2      SEM3 Grade  Placed
# 3  Mary        N   7.7   8.0  8.992857     B       0

# %%
print(hi2.loc[hi2.index==3,"Grade"])
# Out:
# 3    B
# Name: Grade, dtype: object

# %%
#column!!
columns = hi2.columns #view and save columns!!
print(columns)
# Out:
# Index(['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed'], dtype='object')

# %%
#column!!
collist = list(hi2.columns) #view and save columns!!
print(collist)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
#Renaming a column
hi2["Conduct"]="Good"
hi2
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed Conduct
# 0      Joe        K  9.800000  10.0   9.900000    A+       1    Good
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1    Good
# 2   Kissan        V  9.900000   9.8  10.000000     A       0    Good
# 3     Mary        N  7.700000   8.0   8.992857     B       0    Good
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1    Good
# 5      Raj        M  8.900000   9.1   9.300000     A       1    Good
# 6   Hassan        V  9.900000   9.0   9.200000     A       1    Good
# 7     Mari        N  7.700000   8.0   7.100000     B       1    Good
# 8     Jess        K  8.992857   9.1   9.900000    A+       1    Good
# 9   Rajini        M  8.992857   9.1   9.300000     A       0    Good
# 10   Kiran        V  8.992857   9.3   9.200000     A       0    Good
# 11    Maya        N  7.700000   8.0   7.100000     B       0    Good
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1    Good
# ...

# %%
#creat a new col avg with avg values of SEM1,SEM2,SEM3
val=(hi["SEM1"]+hi["SEM2"]+hi["SEM3"])/3
hi['Average'] =val

# %%
hi
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed   Average
# 0      Joe        K   9.8  10.0   9.9    A+       1  9.900000
# 1   Rajesh        M   8.9   9.1   9.3     A       1  9.100000
# 2   Kissan        V   9.9   9.8  10.0     A       0  9.900000
# 4     Jeen        K   9.8   9.1   9.9    A+       1  9.600000
# 5      Raj        M   8.9   9.1   9.3     A       1  9.100000
# 6   Hassan        V   9.9   9.0   9.2     A       1  9.366667
# 7     Mari        N   7.7   8.0   7.1     B       1  7.600000
# 11    Maya        N   7.7   8.0   7.1     B       0  7.600000
# 12   Jolin        K   9.8   9.1   9.9    A+       1  9.600000
# 14    Riya        M   9.3   9.9  10.0     A       1  9.733333
# 15    Sana        V   9.9   9.3   9.2     A       0  9.466667
# 16    Mark        N   7.7   8.0   7.0     B       0  7.566667

# %% [markdown]
# DATA VISUALISATION USING **PANDAAS**

# %%
#plotting with pandas
hi2["SEM1"].plot.line() #dfname['col'].plot.line()
# Out:
# <Axes: >

# %%
hi2[['SEM1','SEM2']].plot.line() #ploting multiple col
# Out:
# <Axes: >

# %%
hi2[['SEM1','SEM2']].plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
hi.plot(kind="scatter",x="Names",y="Average")
# Out:
# <Axes: xlabel='Names', ylabel='Average'>

# %%
hi.plot(kind="scatter",x="Average",y="Names")
# Out:
# <Axes: xlabel='Average', ylabel='Names'>

# %%
hi.plot(kind="hist",x="Names",y="Average")  #y-axis----> numeric
# Out:
# <Axes: ylabel='Frequency'>

# %%
hi.to_csv("hi.csv")
